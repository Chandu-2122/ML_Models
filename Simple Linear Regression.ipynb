# %% [markdown]
# # Importing Libraries

# %%
#import all the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# # Importing the Dataset

# %%
#import the dataset

dataset = pd.read_csv('C:\\Users\\Chandu\\Desktop\\Datasets\\SAT-GPA.csv')

# %% [markdown]
# # Observing the Dataset

# %%
#observe the dataset

dataset
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %% [markdown]
# This dataset gives us the information about the SAT scores and GPA.
# By using the simple linear regression, let's predict the SAT score based on the GPA.

# %% [markdown]
# # Preprocessing the Dataset

# %%
#Getting the basic information of the dataset

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SAT     84 non-null     int64
#  1   GPA     84 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.4 KB

# %% [markdown]
# This dataset has 84 entries of SAT and GPA values of which SAT is of integer and GPA is of float datatype.

# %%
#Let's seperately check for only null values

dataset.isnull().sum()
# Out:
# SAT    0
# GPA    0
# dtype: int64

# %% [markdown]
# This tells us that none of the columns in the dataset has null values.

# %% [markdown]
# # Visualizing the Data

# %%
#Lets draw a graph between SAT and GPA scores

plt.figure(figsize=(40,20))
plt.plot(dataset["GPA"], dataset["SAT"])
plt.xlabel('GPA')
plt.ylabel('SAT')
plt.show()

# %% [markdown]
# # Dividing into input and output

# %% [markdown]
# Since, the students having higher GPA will probably have a higher SAT score, let's take the GPA as the independent factor(x) and the SAT score as the dependent factor(y)

# %%
#Let's take the GPA as 'x-values'(input) and SAT scores as 'y-values'(output).

x = dataset["GPA"].values
y = dataset["SAT"].values

# %%
#Let's see the shape of x

x.shape
# Out:
# (84,)

# %% [markdown]
# Since our x(input) values should be a 2-D array, let us reshape this 1-D array into a 2-D array.

# %%
#Let's reshape x

x = x.reshape(84,1)
x.shape
# Out:
# (84, 1)

# %%
#Let's see the x values
x
# Out:
# array([[2.4 ],
#        [2.52],
#        [2.54],
#        [2.74],
#        [2.83],
#        [2.91],
#        [3.  ],
#        [3.  ],
#        [3.01],
#        [3.01],
#        [3.02],
#        [3.07],
#        [3.08],
#        [3.08],
#        [3.12],
#        [3.17],
#        [3.17],
#        [3.17],
#        [3.17],
#        [3.19],
#        [3.19],
#        [3.19],
#        [3.2 ],
#        [3.21],
#        [3.24],
#        [3.28],
#        [3.28],
#        [3.28],
#        [3.28],
#        [3.28],
#        [3.28],
#        [3.28],
#        [3.29],
#        [3.29],
#        [3.29],
#        [3.31],
#        [3.32],
#        [3.34],
#        [3.37],
#        [3.37],
#        [3.37],
#        [3.38],
#        [3.38],
#        [3.39],
#        [3.39],
#        [3.4 ],
#        [3.4 ],
#        [3.4 ],
#        [3.41],
#        [3.41],
#        [3.41],
#        [3.42],
#        [3.42],
#        [3.42],
#        [3.44],
#        [3.47],
#        [3.47],
#        [3.47],
# ...

# %%
#Let's see the y values

y
# Out:
# array([1714, 1664, 1760, 1685, 1693, 1670, 1764, 1764, 1792, 1850, 1735,
#        1775, 1735, 1712, 1773, 1872, 1755, 1674, 1842, 1786, 1761, 1722,
#        1663, 1687, 1974, 1826, 1787, 1821, 2020, 1794, 1769, 1934, 1775,
#        1855, 1880, 1849, 1808, 1954, 1777, 1831, 1865, 1850, 1966, 1702,
#        1990, 1925, 1824, 1956, 1857, 1979, 1802, 1855, 1907, 1634, 1879,
#        1887, 1730, 1953, 1781, 1891, 1964, 1808, 1893, 2041, 1893, 1832,
#        1850, 1934, 1861, 1931, 1933, 1778, 1975, 1934, 2021, 2015, 1997,
#        2020, 1843, 1936, 1810, 1987, 1962, 2050], dtype=int64)

# %%
#Let's see the shape of y

y.shape
# Out:
# (84,)

# %% [markdown]
# # Dividing the dataset into Train and Test parts

# %%
#Let's split the dataset into testing and training part

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
#Let's see the size of x_train and y_train dataparts

x_train.size, y_train.size
# Out:
# (67, 67)

# %%
#Let's see the shape of x_train and y_train dataparts

x_train.shape, y_train.shape
# Out:
# ((67, 1), (67,))

# %%
#Let's see the size of x_test and y_test dataparts

x_test.size, y_test.size
# Out:
# (17, 17)

# %% [markdown]
# # Running a Regressor

# %%
#Let's run a regressor to get the predicted values of GPA based on the SAT scores.

lr = LinearRegression()

# %% [markdown]
# # Fitting the model

# %%
#Let's fit the model by mapping the input with output of the training dataset.

lr = lr.fit(x_train, y_train)

# %% [markdown]
# # Predicting the output

# %%
#Let's predict the output values(y_test) based on the input values(x_test)

y_pred = lr.predict(x_test)
y_pred
# Out:
# array([1848.07614057, 1825.54973684, 1757.97052562, 1815.53800184,
#        1825.54973684, 1605.29156696, 1933.17588803, 1775.49106186,
#        1958.20522551, 1918.15828554, 1825.54973684, 1860.59080932,
#        1853.08200807, 1755.46759188, 1908.14655054, 1803.0233331 ,
#        1825.54973684])

# %%
#Let's see the actual output values(y_test)

y_test
# Out:
# array([1777, 2020, 1792, 1974, 1794, 1714, 1843, 1712, 2050, 2020, 1821,
#        1855, 1990, 1764, 2021, 1722, 1826], dtype=int64)

# %%
#Let's see the difference between the actual and the predicted output values

y_test - y_pred
# Out:
# array([-71.07614057, 194.45026316,  34.02947438, 158.46199816,
#        -31.54973684, 108.70843304, -90.17588803, -63.49106186,
#         91.79477449, 101.84171446,  -4.54973684,  -5.59080932,
#        136.91799193,   8.53240812, 112.85344946, -81.0233331 ,
#          0.45026316])

# %%
#Let's see the graphical representation of the actual and the predicted output values

#let's point the actual output values(y_test) vs the actual input values(x_test)
plt.scatter(x_test, y_test)

#let's point the predicted output values(y_pred) vs the actual input values(x_test)
plt.plot(x_test, y_pred, 'r')

# %% [markdown]
# # Evaluating the Accuracy score of the model

# %%
#Let's check the accuracy score of the model

r2_score(y_test, y_pred)
# Out:
# 0.35195230536922706

# %%
import  statsmodels.api as sm

# %%
model = sm.OLS(y_train,x_train).fit()
predictions = model.predict(x_train)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.996
# Method:                 Least Squares   F-statistic:                          1.906e+04
# Date:                Thu, 01 Sep 2022   Prob (F-statistic):                    5.54e-83
# Time:                        20:35:47   Log-Likelihood:                         -408.94
# No. Observations:                  67   AIC:                                      819.9
# Df Residuals:                      66   BIC:                                      822.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model = sm.OLS(y_test,x_test).fit()
predictions = model.predict(x_test)

model.summary()
# Out:
# C:\Users\Chandu\anaconda3\lib\site-packages\scipy\stats\stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=17
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared (uncentered):                   0.995
# Model:                            OLS   Adj. R-squared (uncentered):              0.995
# Method:                 Least Squares   F-statistic:                              3087.
# Date:                Thu, 01 Sep 2022   Prob (F-statistic):                    9.83e-20
# Time:                        20:35:47   Log-Likelihood:                         -107.40
# No. Observations:                  17   AIC:                                      216.8
# Df Residuals:                      16   BIC:                                      217.6
# Df Model:                           1
# ...
